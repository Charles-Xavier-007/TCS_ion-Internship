# %%
import string
from collections import Counter

import matplotlib.pyplot as plt

# reading text or csv(excel) file
text = open("emobank.csv",encoding="utf-8").read()

# converting to lowercase
lower_case = text.lower()

#Removing punctuations
cleaned_text = lower_case.translate(str.maketrans('', '', string.punctuation))

# splitting text into words
tokenized_words = cleaned_text.split()

stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself",
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these",
              "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do",
              "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while",
              "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before",
              "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again",
              "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each",
              "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
              "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# Remoivng stop words from the tokenized words list
final_words = []
for word in tokenized_words:
    if word not in stop_words:
        final_words.append(word)

# NLP Emotion Algorithm
# 1) Check if the word in the final word list is also present in emotion.txt
#  - open the emotion file
#  - Loop through each line and clear it
#  - Extract the word and emotion using split

# 2) If word is present -> Add the emotion to emotion_list
# 3) Finally count each emotion in the emotion list

emotion_list = []
with open('emotion.txt','r') as file:
    for line in file:
        clear_line = line.replace("\n",'').replace("'", '').strip()
        word,emotion = clear_line.split(":")

        if word in final_words:
            emotion_list.append(emotion)

print(emotion_list)
w = Counter(emotion_list)
print(w)

# Plotting the emotions on the graph

fig, ax1 = plt.subplots()
ax1.bar(w.keys(),w.values())
fig.autofmt_xdate()
plt.savefig('graph.png')
plt.show()
# Out:
# [' cheated,', ' cheated,', ' loved,', ' attracted,', ' fearful,', ' happy,', ' happy,', ' angry,', ' attracted,', ' angry,', ' esteemed,', ' attached,', ' attracted,', ' independent,', ' embarrassed,', ' attached,', ' angry,', ' powerless,', ' sad,', ' fearless,', ' bored,', ' fearless,', ' happy,', ' safe,', ' adequate,', ' singled out,', ' fearless,', ' attracted,', ' hated,', ' happy,', ' attached,', ' fearful,', ' happy,', ' average,', ' adequate,', ' adequate,', ' attracted,', ' adequate,', ' surprise,', ' attached,', ' obsessed,', ' powerless,', ' entitled,', ' fearless,', ' hated,', ' angry,', ' sad,', ' attracted,', ' fearless,', ' sad,', ' attracted,', ' powerless,', ' sad,', ' hated,', ' loved,', ' focused,', ' demoralized,', ' belittled,', ' powerless,', ' angry,', ' sad,', ' sad,', ' sad,', ' anxious,', ' sad,', ' attracted,', ' embarrassed,', ' attracted,', ' adequate,', ' happy,', ' esteemed,', ' happy,', ' entitled,', ' cheated,', ' fearful,', ' ecstatic,', ' ecstatic,', ' attracted,', ' entitled,', ' sad,', ' focused,', ' powerless,', ' cheated,', ' free,', ' fearful,', ' angry,', ' happy,', ' happy,', ' sad,', ' singled out,', ' happy,', ' fearless,', ' sad,', ' attracted,', ' fearful,', ' sad,', ' fearful,', ' hated,', ' happy,', ' angry,', ' attached,', ' free,', ' angry,', ' sad,', ' attracted,', ' attracted,', ' attracted,', ' angry,', ' alone,', ' happy,', ' happy,', ' happy,', ' singled out,', ' singled out,', ' apathetic,', ' apathetic,', ' attached,', ' happy,', ' alone,', ' lost,', ' attached,', ' sad,', ' happy,', ' angry,', ' sad,', ' alone,', ' attracted,', ' attracted,', ' codependent,', ' fearful,', ' sad,', ' average,', ' adequate,', ' angry,', ' lustful,', ' sad,', ' safe,', ' anxious,', ' happy,', ' happy,', ' powerless,', ' burdened,', ' happy,', ' hated,', ' singled out,', ' powerless,', ' singled out,', ' alone,', ' free,', ' hated,', ' esteemed,', ' adequate,', ' esteemed,', ' sad,', ' happy,', ' fearful,', ' fearless,', ' surprise,', ' esteemed,', ' anxious,', ' sad,', ' happy,', ' powerless,', ' independent,', ' sad,', ' happy,', ' surprise,', ' anxious,', ' codependent,', ' happy,', ' fearful,', ' powerless,', ' derailed,', ' sad,', ' sad,', ' happy,', ' entitled,', ' anxious,', ' attached,', ' fearful,', ' esteemed,', ' sad,', ' cheated,', ' powerless,', ' powerless,', ' loved,', ' fearful,', ' lustful,', ' fearful,', ' hated,', ' powerless,', ' loved,', ' codependent,', ' esteemed,', ' fearful,', ' happy,', ' alone,', ' independent,', ' embarrassed,', ' surprise,', ' fearful,', ' free,', ' average,', ' focused,', ' obsessed,', ' ecstatic,', ' powerless,', ' entitled,', ' adequate,', ' happy,', ' hated,', ' fearless,', ' happy,', ' attracted,', ' singled out,', ' loved,', ' attached,', ' sad,', ' cheated,', ' apathetic,', ' happy,', ' powerless,', ' anxious,', ' hated,', ' esteemed,', ' fearful,', ' happy,', ' entitled,', ' fearful,', ' anxious,', ' sad,']
# Counter({' happy,': 29, ' sad,': 25, ' attracted,': 17, ' fearful,': 16, ' powerless,': 14, ' angry,': 11, ' attached,': 9, ' hated,': 9, ' esteemed,': 8, ' fearless,': 8, ' adequate,': 8, ' singled out,': 7, ' anxious,': 7, ' cheated,': 6, ' entitled,': 6, ' loved,': 5, ' alone,': 5, ' surprise,': 4, ' free,': 4, ' independent,': 3, ' embarrassed,': 3, ' average,': 3, ' focused,': 3, ' ecstatic,': 3, ' apathetic,': 3, ' codependent,': 3, ' safe,': 2, ' obsessed,': 2, ' lustful,': 2, ' bored,': 1, ' demoralized,': 1, ' belittled,': 1, ' lost,': 1, ' burdened,': 1, ' derailed,': 1})
